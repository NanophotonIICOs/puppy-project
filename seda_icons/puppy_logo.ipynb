# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt


files = ! ls *.png
puppy_icon = Image.open(files[0])
# puppy_icon.putalpha(230)
d = ImageDraw.Draw(puppy_icon)
font = ImageFont.truetype("fonts/Wigglye.ttf", size=100)
font2 = ImageFont.truetype("fonts/Wigglye.ttf", size=70)
font3 = ImageFont.truetype("fonts/Wigglye.ttf", size=36)

d.text((170,100), "SEDA",font=font)
d.text((230,200), "by",font=font2)
d.text((170,250), "Puppy",font=font)
d.text((0,400), "Spectroscopy Experimental Data Analysis",font=font3)
puppy_icon.save('puppy_icon.png')

plt.figure(figsize=(10,10))
plt.imshow(puppy_icon)
plt.show()

# %%
puppy_icon
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512>
